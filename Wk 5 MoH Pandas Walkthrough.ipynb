# %% [markdown]
# # Pandas Demo
#
# This demo works through importing pandas and using it to research a csv file.  CSV file must be found and imported.

# %%
# Review class recording to find CSV on kaggle.  Most open CSV in VSC prior to importing.  Is there a military awards csv, MoH?

# Iports pandas and changes the name to shorthand pd
import pandas as pd

#create a dataframe object from a csv
# Takes already sorted CSV data and resorts for our use.
# tell pandas to read a file name within the () and 
moh_df = pd.read_csv('medal_of_honor.csv', delimiter=",")

moh_df
# Out:
#       death                    name  awarded.General Order number  \
# 0      True     Sagelhurst, John C.                            -1
# 1      True              Hack, John                            -1
# 2      True      Carson, Anthony J.                            -1
# 3      True    Defranzos, Arthur F.                             1
# 4      True     Kessler, Patrick L.                             1
# ...     ...                     ...                           ...
# 3470   True        Yeager, Jacob F.                            -1
# 3471   True  Yntema, Gordon Douglas                            -1
# 3472   True        Young, Andrew J.                            -1
# 3473   True      Young, Benjamin F.                            -1
# 3474   True       Young, Calvary M.                            -1
#
#      awarded.accredited to                                   awarded.citation  \
# 0                      NaN  Under a heavy fire from the enemy carried off ...
# 1                      NaN  Was one of a party which volunteered and attem...
# 2                      NaN  Assumed command of a detachment of the company...
# 3                      NaN  For conspicuous gallantry and intrepidity at t...
# 4                      NaN  For conspicuous gallantry and intrepidity at r...
# ...                    ...                                                ...
# 3470                   NaN  Seized a shell with fuze burning that had fall...
# 3471                   NaN  For conspicuous gallantry and intrepidity in a...
# 3472                   NaN                                   Capture of flag.
# 3473                   NaN  Capture of flag of 35th North Carolina Infantr...
# 3474                   NaN                Gallantry in capturing Gen. Cabell.
#
#      awarded.issued      birth.location name  \
# 0        01/03/1906            Buffalo, N.Y.
# 1        01/03/1907            1843, Germany
# 2        01/04/1906            Boston, Mass.
# 3        01/04/1945            Saugus, Mass.
# 4        01/04/1945         Middletown, Ohio
# ...             ...                      ...
# 3470              ?       Lehigh County, Pa.
# 3471              ?            Bethesda, Md.
# 3472              ?       Greene County, Pa.
# 3473              ?             1844, Canada
# 3474              ?  Washington County, Ohio
#
#                                           metadata.link  \
# 0     http://www.cmohs.org/recipient-detail/1176/sag...
# 1     http://www.cmohs.org/recipient-detail/537/hack...
# 2     http://www.cmohs.org/recipient-detail/2211/car...
# 3     http://www.cmohs.org/recipient-detail/2710/def...
# 4     http://www.cmohs.org/recipient-detail/2824/kes...
# ...                                                 ...
# 3470  http://www.cmohs.org/recipient-detail/1531/yea...
# 3471  http://www.cmohs.org/recipient-detail/3454/ynt...
# 3472  http://www.cmohs.org/recipient-detail/1532/you...
# 3473  http://www.cmohs.org/recipient-detail/1533/you...
# 3474  http://www.cmohs.org/recipient-detail/1534/you...
#
#      military record.company             military record.division  ...  \
# 0                  Company B               1st New Jersey Cavalry  ...
# 1                  Company B                   47th Ohio Infantry  ...
# 2                  Company H                         43d Infantry  ...
# 3                        NaN                1st Infantry Division  ...
# 4                  Company K  30th Infantry, 3d Infantry Division  ...
# ...                      ...                                  ...  ...
# 3470               Company H                  101st Ohio Infantry  ...
# 3471               Company D             5th Special Forces Group  ...
# 3472               Company F             1st Pennsylvania Cavalry  ...
# 3473               Company I           1st Michigan Sharpshooters  ...
# 3474               Company L                      3d Iowa Cavalry  ...
#
#      awarded.date.day awarded.date.full awarded.date.month  awarded.date.year  \
# 0                   6          1865-2-6                  2               1865
# 1                   3          1863-5-3                  5               1863
# 2                  -1          -1--1--1                 -1                 -1
# 3                  10         1944-6-10                  6               1944
# 4                  23         1944-5-23                  5               1944
# ...               ...               ...                ...                ...
# 3470               11         1864-5-11                  5               1864
# 3471               -1          -1--1--1                 -1                 -1
# 3472                5          1865-4-5                  4               1865
# 3473               17         1864-6-17                  6               1864
# 3474               25        1864-10-25                 10               1864
#
#      awarded.location.latitude  awarded.location.longitude  \
# 0                           38                         -77
# 1                           32                         -90
# 2                           10                         124
# 3                           49                           0
# 4                           43                          11
# ...                        ...                         ...
# 3470                        31                         -81
# 3471                        10                         106
# 3472                        37                         -78
# 3473                        37                         -77
# 3474                        38                         -95
#
#                                   awarded.location.name  birth.date.day  \
# 0           Hatchers Run Court, Stafford, VA 22554, USA              -1
# 1                                    Vicksburg, MS, USA              -1
# 2                                    Leyte, Philippines              -1
# 3                                14490 Vaubadon, France              -1
# 4                           50026 Ponte Rotto FI, Italy              -1
# ...                                                 ...             ...
# 3470           Buzzards Roost, Brunswick, GA 31520, USA              -1
# 3471  Honorary Consulate General of the Republic of ...              26
# 3472                                      Virginia, USA              -1
# 3473                                Petersburg, VA, USA              -1
# 3474                              Osage County, KS, USA              -1
#
#       birth.date.month birth.date.year
# 0                   -1              -1
# 1                   -1              -1
# 2                   -1              -1
# 3                   -1              -1
# 4                   -1              -1
# ...                ...             ...
# 3470                -1              -1
# 3471                 6            1945
# 3472                -1              -1
# 3473                -1              -1
# 3474                -1              -1
#
# [3475 rows x 23 columns]

# %%
# Prints top 10 rows plus header
moh_df.head(10)
# Out:
#    death                   name  awarded.General Order number  \
# 0   True    Sagelhurst, John C.                            -1
# 1   True             Hack, John                            -1
# 2   True     Carson, Anthony J.                            -1
# 3   True   Defranzos, Arthur F.                             1
# 4   True    Kessler, Patrick L.                             1
# 5   True   Pinder, John J., Jr.                             1
# 6   True    Vance, Leon R., Jr.                             1
# 7   True  Boers, Edward William                            13
# 8   True       Brock, George F.                            13
# 9   True       Clausey, John J.                            13
#
#   awarded.accredited to                                   awarded.citation  \
# 0                   NaN  Under a heavy fire from the enemy carried off ...
# 1                   NaN  Was one of a party which volunteered and attem...
# 2                   NaN  Assumed command of a detachment of the company...
# 3                   NaN  For conspicuous gallantry and intrepidity at t...
# 4                   NaN  For conspicuous gallantry and intrepidity at r...
# 5                   NaN  For conspicuous gallantry and intrepidity abov...
# 6                   NaN  For conspicuous gallantry and intrepidity abov...
# 7              Kentucky  On board the U.S.S. Bennington, 21 July 1905. ...
# 8            California  Serving on board the U.S.S. Bennington for ext...
# 9            California  On board the U.S.S. Bennington for extraordina...
#
#   awarded.issued     birth.location name  \
# 0     01/03/1906           Buffalo, N.Y.
# 1     01/03/1907           1843, Germany
# 2     01/04/1906           Boston, Mass.
# 3     01/04/1945           Saugus, Mass.
# 4     01/04/1945        Middletown, Ohio
# 5     01/04/1945       McKees Rocks, Pa.
# 6     01/04/1945             Enid, Okla.
# 7     01/05/1906        Cincinnati, Ohio
# 8     01/05/1906         Cleveland, Ohio
# 9     01/05/1906   San Francisco, Calif.
#
#                                        metadata.link military record.company  \
# 0  http://www.cmohs.org/recipient-detail/1176/sag...               Company B
# 1  http://www.cmohs.org/recipient-detail/537/hack...               Company B
# 2  http://www.cmohs.org/recipient-detail/2211/car...               Company H
# 3  http://www.cmohs.org/recipient-detail/2710/def...                     NaN
# 4  http://www.cmohs.org/recipient-detail/2824/kes...               Company K
# 5  http://www.cmohs.org/recipient-detail/2951/pin...                     NaN
# 6  http://www.cmohs.org/recipient-detail/3033/van...                     NaN
# 7  http://www.cmohs.org/recipient-detail/2350/boe...                     NaN
# 8  http://www.cmohs.org/recipient-detail/2354/bro...                     NaN
# 9  http://www.cmohs.org/recipient-detail/2357/cla...                     NaN
#
#                military record.division  ... awarded.date.day  \
# 0                1st New Jersey Cavalry  ...                6
# 1                    47th Ohio Infantry  ...                3
# 2                          43d Infantry  ...               -1
# 3                 1st Infantry Division  ...               10
# 4   30th Infantry, 3d Infantry Division  ...               23
# 5  16th Infantry, 1st Infantry Division  ...                6
# 6                    489th Bomber Group  ...                5
# 7                                   NaN  ...               -1
# 8                                   NaN  ...               -1
# 9                                   NaN  ...               -1
#
#   awarded.date.full awarded.date.month  awarded.date.year  \
# 0          1865-2-6                  2               1865
# 1          1863-5-3                  5               1863
# 2          -1--1--1                 -1                 -1
# 3         1944-6-10                  6               1944
# 4         1944-5-23                  5               1944
# 5          1944-6-6                  6               1944
# 6          1944-6-5                  6               1944
# 7          -1--1--1                 -1                 -1
# 8          -1--1--1                 -1                 -1
# 9          -1--1--1                 -1                 -1
#
#   awarded.location.latitude  awarded.location.longitude  \
# 0                        38                         -77
# 1                        32                         -90
# 2                        10                         124
# 3                        49                           0
# 4                        43                          11
# 5                        49                           0
# 6                        50                           1
# 7                        -1                          -1
# 8                        32                        -117
# 9                        32                        -117
#
#                          awarded.location.name  birth.date.day  \
# 0  Hatchers Run Court, Stafford, VA 22554, USA              -1
# 1                           Vicksburg, MS, USA              -1
# 2                           Leyte, Philippines              -1
# 3                       14490 Vaubadon, France              -1
# 4                  50026 Ponte Rotto FI, Italy              -1
# 5                   Colleville-sur-Mer, France              -1
# 6                             Wimereux, France              11
# 7                                          NaN              10
# 8                           San Diego, CA, USA              18
# 9                           San Diego, CA, USA              16
#
#    birth.date.month birth.date.year
# 0                -1              -1
# 1                -1              -1
# 2                -1              -1
# 3                -1              -1
# 4                -1              -1
# 5                -1              -1
# 6                 8            1916
# 7                 3            1884
# 8                10            1872
# 9                 5            1875
#
# [10 rows x 23 columns]

# %%
# Prints the min, mean, and max of a time, date, year...
print(moh_df['awarded.date.year'].min())
print(moh_df['awarded.date.year'].mean())
print(moh_df['awarded.date.year'].max())
print(moh_df['birth.date.year'].min())
print(moh_df['birth.date.year'].mean())
print(moh_df['birth.date.year'].max())
# The -1 printed reflects unavailable data in these columns.  Potetially becasue data was unavailable, especially for birth year.
# The decimal numbers reflect the math done to achive a mean of the numbers, not an actual mean year.
# Out:
# -1
# 1200.1476258992807
# 2007
# -1
# 605.0705035971223
# 1988

# %%
# Gives arandom sample of data within the provided range
moh_df.sample(10)
# Out:
#       death                  name  awarded.General Order number  \
# 2060   True      Kelly, Alexander                            -1
# 718    True  Reid, George Croghan                           177
# 1895   True      Horne, Samuel B.                            -1
# 2714   True     Powers, Wesley J.                            -1
# 2821   True          Roche, David                            -1
# 817    True    Kelly, John Joseph                            16
# 2730   True      Purman, James J.                            -1
# 2969   True   Sickles, William H.                            -1
# 118    True    Moskala, Edward J.                            21
# 1659   True         Gomez, Edward                            -1
#
#      awarded.accredited to                                   awarded.citation  \
# 2060                   NaN  Gallantly seized the colors, which had fallen ...
# 718                   Ohio  For distinguished conduct in battle, engagemen...
# 1895                   NaN  While acting as an aide and carrying an import...
# 2714                   NaN  Voluntarily swam the river under heavy fire an...
# 2821                   NaN                               Gallantry in action.
# 817               Illinois  Also received the Army Medal of Honor. Pvt. Ke...
# 2730                   NaN  Voluntarily assisted a wounded comrade to a pl...
# 2969                   NaN  With a comrade, attempted capture of a stand o...
# 118                    NaN  He was the leading element when grenade explos...
# 1659                   NaN  For conspicuous gallantry and intrepidity at t...
#
#      awarded.issued birth.location name  \
# 2060              ?        Pennsylvania
# 718      12/04/1915        Lorain, Ohio
# 1895              ?             Ireland
# 2714              ?              Canada
# 2821              ?             Ireland
# 817      12/31/1919       Chicago, Ill.
# 2730              ?                 NaN
# 2969              ?        Danube, N.Y.
# 118      02/26/1946       Chicago, Ill.
# 1659              ?        Omaha, Nebr.
#
#                                           metadata.link  \
# 2060  http://www.cmohs.org/recipient-detail/740/kell...
# 718   http://www.cmohs.org/recipient-detail/2443/rei...
# 1895  http://www.cmohs.org/recipient-detail/645/horn...
# 2714  http://www.cmohs.org/recipient-detail/1086/pow...
# 2821  http://www.cmohs.org/recipient-detail/1853/roc...
# 817   http://www.cmohs.org/recipient-detail/2550/kel...
# 2730  http://www.cmohs.org/recipient-detail/1094/pur...
# 2969  http://www.cmohs.org/recipient-detail/1245/sic...
# 118   http://www.cmohs.org/recipient-detail/2900/mos...
# 1659  http://www.cmohs.org/recipient-detail/3117/gom...
#
#       military record.company               military record.division  ...  \
# 2060                Company F                6th U.S. Colored Troops  ...
# 718                       NaN                                    NaN  ...
# 1895                Company H              11th Connecticut Infantry  ...
# 2714                Company F                147th Illinois Infantry  ...
# 2821                Company A                      5th U.S. Infantry  ...
# 817              78th Company              6th Regiment, 2d Division  ...
# 2730                Company A            140th Pennsylvania Infantry  ...
# 2969                Company B                 7th Wisconsin Infantry  ...
# 118                 Company C  383d Infantry, 96th Infantry Division  ...
# 1659  Company E, 2d Battalion       1st Marines, 1st Marine Division  ...
#
#      awarded.date.day awarded.date.full awarded.date.month  awarded.date.year  \
# 2060               29         1864-9-29                  9               1864
# 718                -1          -1--1--1                 -1                 -1
# 1895               29         1864-9-29                  9               1864
# 2714                3          1865-4-3                  4               1865
# 2821               -1          -1--1--1                 -1                 -1
# 817                 3         1918-10-3                 10               1918
# 2730                2          1863-7-2                  7               1863
# 2969               31         1865-3-31                  3               1865
# 118                 9          1945-4-9                  4               1945
# 1659               14         1951-9-14                  9               1951
#
#      awarded.location.latitude  awarded.location.longitude  \
# 2060                        36                         -76
# 718                         19                         -96
# 1895                        37                         -77
# 2714                        34                         -85
# 2821                        46                        -110
# 817                         46                           2
# 2730                        39                         -77
# 2969                        37                         -77
# 118                         26                         127
# 1659                        60                          10
#
#                                   awarded.location.name  birth.date.day  \
# 2060              Chapin Street, Norfolk, VA 23503, USA              -1
# 718                  Heroica Veracruz, Veracruz, Mexico               9
# 1895  Fort Harrison, 8621 Battlefield Park Road, Hen...               3
# 2714                 Oostanaula, Calhoun, GA 30701, USA              -1
# 2821                                       Montana, USA              -1
# 817                                              France              24
# 2730                          Gettysburg, PA 17325, USA              -1
# 2969                           Gravelly Run, 4, VA, USA              -1
# 118                           Okinawa Prefecture, Japan               6
# 1659                                 Koreavegen, Norway              10
#
#       birth.date.month birth.date.year
# 2060                -1              -1
# 718                 12            1876
# 1895                 3            1843
# 2714                -1              -1
# 2821                -1              -1
# 817                  6            1898
# 2730                -1              -1
# 2969                -1              -1
# 118                 11            1921
# 1659                 8            1932
#
# [10 rows x 23 columns]

# %%
# I think this breaks out various aspects of data, like proportions
moh_df.describe(include='all')
# Out:
#        death          name  awarded.General Order number  \
# count   3475          3475                   3475.000000
# unique     1          3429                           NaN
# top     True  Smith, James                           NaN
# freq    3475             4                           NaN
# mean     NaN           NaN                     34.828489
# std      NaN           NaN                     94.067134
# min      NaN           NaN                     -1.000000
# 25%      NaN           NaN                     -1.000000
# 50%      NaN           NaN                     -1.000000
# 75%      NaN           NaN                     32.000000
# max      NaN           NaN                    537.000000
#
#        awarded.accredited to      awarded.citation awarded.issued  \
# count                    822                  3475           3475
# unique                   107                  2965            410
# top                 New York  Gallantry in action.              ?
# freq                     230                   123           2602
# mean                     NaN                   NaN            NaN
# std                      NaN                   NaN            NaN
# min                      NaN                   NaN            NaN
# 25%                      NaN                   NaN            NaN
# 50%                      NaN                   NaN            NaN
# 75%                      NaN                   NaN            NaN
# max                      NaN                   NaN            NaN
#
#        birth.location name                                      metadata.link  \
# count                 3358                                               3475
# unique                2248                                               3475
# top                Ireland  http://www.cmohs.org/recipient-detail/2778/har...
# freq                   150                                                  1
# mean                   NaN                                                NaN
# std                    NaN                                                NaN
# min                    NaN                                                NaN
# 25%                    NaN                                                NaN
# 50%                    NaN                                                NaN
# 75%                    NaN                                                NaN
# max                    NaN                                                NaN
#
#        military record.company military record.division  ... awarded.date.day  \
# count                     2070                     2519  ...      3475.000000
# unique                     174                     1008  ...              NaN
# top                  Company B         8th U.S. Cavalry  ...              NaN
# freq                       202                       91  ...              NaN
# mean                       NaN                      NaN  ...        17.033094
# std                        NaN                      NaN  ...       118.101643
# min                        NaN                      NaN  ...        -1.000000
# 25%                        NaN                      NaN  ...        -1.000000
# 50%                        NaN                      NaN  ...         5.000000
# 75%                        NaN                      NaN  ...        19.000000
# max                        NaN                      NaN  ...      1876.000000
#
#        awarded.date.full awarded.date.month  awarded.date.year  \
# count               3475        3475.000000        3475.000000
# unique               937                NaN                NaN
# top             -1--1--1                NaN                NaN
# freq                1259                NaN                NaN
# mean                 NaN           3.837410        1200.147626
# std                  NaN           4.381463         913.697602
# min                  NaN          -1.000000          -1.000000
# 25%                  NaN          -1.000000          -1.000000
# 50%                  NaN           4.000000        1864.000000
# 75%                  NaN           7.000000        1880.500000
# max                  NaN          12.000000        2007.000000
#
#        awarded.location.latitude  awarded.location.longitude  \
# count                3475.000000                 3475.000000
# unique                       NaN                         NaN
# top                          NaN                         NaN
# freq                         NaN                         NaN
# mean                   30.945612                  -29.143022
# std                    13.886504                   84.744501
# min                   -57.000000                 -171.000000
# 25%                    30.000000                  -87.000000
# 50%                    35.000000                  -77.000000
# 75%                    38.000000                    7.000000
# max                    90.000000                  176.000000
#
#                                     awarded.location.name  birth.date.day  \
# count                                                3373     3475.000000
# unique                                                925             NaN
# top     Honorary Consulate General of the Republic of ...             NaN
# freq                                                  179             NaN
# mean                                                  NaN        4.206331
# std                                                   NaN        9.090618
# min                                                   NaN       -1.000000
# 25%                                                   NaN       -1.000000
# 50%                                                   NaN       -1.000000
# 75%                                                   NaN        7.000000
# max                                                   NaN       31.000000
#
#         birth.date.month birth.date.year
# count        3475.000000     3475.000000
# unique               NaN             NaN
# top                  NaN             NaN
# freq                 NaN             NaN
# mean            1.414388      605.070504
# std             4.035867      884.464961
# min            -1.000000       -1.000000
# 25%            -1.000000       -1.000000
# 50%            -1.000000       -1.000000
# 75%             3.000000     1856.000000
# max            12.000000     1988.000000
#
# [11 rows x 23 columns]

# %%
# Prints the count of a particualr vaule within a column
moh_df['military record.organization'].value_counts()
# Out:
# U.S. Army            2428
# U.S. Navy             734
# U.S. Marine Corps     295
# U.S. Air Force         17
# U.S. Coast Guard        1
# Name: military record.organization, dtype: int64

# %%
# Prints the top X counts of a particular value.  In this case the 10 names that occur the most.
moh_df['name'].value_counts()[:10]
# Out:
# Smith, James          4
# Davis, John           4
# Smith, John           3
# Kelly, Thomas         3
# Smith, Thomas         3
# Williams, John        3
# Kelly, John D.        2
# Campbell, William     2
# Thomas, Charles L.    2
# Smith, Charles H.     2
# Name: name, dtype: int64

# %%
# Visualization.  15 vaule counts, plots out as a bar horizontl, gives title of plot.  
# Pandas is great at making good looking visualizations.  Refer to pandas website.
# This cell created a bar graph numbers of MoH by branch.
moh_df['military record.organization'].value_counts()[:15].plot(kind="barh", title="Most MoH by Branch")

# %%
# Utility function for running queries on data.  
# for Oscar demo: In this case searching awards without a film attached, ex lifetime achievement awards.
# For MoH work, this query doesn't seem to apply.  It runs succesfully, but no reulst apply, maybe.
moh_df['birth.date.year'] = moh_df['birth.date.year'].fillna('No birth year available')

# %%
# This queries the rank column for all earning MoH with the rank of sergeant. 
moh_df[moh_df['military record.rank'].str.contains('Sergeant')]
# Out:
#       death                    name  awarded.General Order number  \
# 0      True     Sagelhurst, John C.                            -1
# 3      True    Defranzos, Arthur F.                             1
# 27     True       Bertoldo, Vito R.                            -1
# 34     True     Collier, Gilbert G.                             3
# 45     True        Dix, Drew Dennis                            -1
# ...     ...                     ...                           ...
# 3468   True           Yabes, Maximo                            -1
# 3469   True      Yano, Rodney J. T.                            -1
# 3471   True  Yntema, Gordon Douglas                            -1
# 3472   True        Young, Andrew J.                            -1
# 3474   True       Young, Calvary M.                            -1
#
#      awarded.accredited to                                   awarded.citation  \
# 0                      NaN  Under a heavy fire from the enemy carried off ...
# 3                      NaN  For conspicuous gallantry and intrepidity at t...
# 27                     NaN  He fought with extreme gallantry while guardin...
# 34                     NaN  Sgt. Collier, a member of Company F, distingui...
# 45              Denver, CO  For conspicuous gallantry and intrepidity in a...
# ...                    ...                                                ...
# 3468                   NaN  For conspicuous gallantry and intrepidity at t...
# 3469                   NaN  Sfc. Yano distinguished himself while serving ...
# 3471                   NaN  For conspicuous gallantry and intrepidity in a...
# 3472                   NaN                                   Capture of flag.
# 3474                   NaN                Gallantry in capturing Gen. Cabell.
#
#      awarded.issued       birth.location name  \
# 0        01/03/1906             Buffalo, N.Y.
# 3        01/04/1945             Saugus, Mass.
# 27       01/10/1946             Decatur, Ill.
# 34       01/12/1955              Hunter, Ark.
# 45       01/16/1969          West Point, N.Y.
# ...             ...                       ...
# 3468              ?              Lodi, Calif.
# 3469              ?   Kealakekua Kona, Hawaii
# 3471              ?             Bethesda, Md.
# 3472              ?        Greene County, Pa.
# 3474              ?   Washington County, Ohio
#
#                                           metadata.link  \
# 0     http://www.cmohs.org/recipient-detail/1176/sag...
# 3     http://www.cmohs.org/recipient-detail/2710/def...
# 27    http://www.cmohs.org/recipient-detail/2637/ber...
# 34    http://www.cmohs.org/recipient-detail/3096/col...
# 45    http://www.cmohs.org/recipient-detail/3263/dix...
# ...                                                 ...
# 3468  http://www.cmohs.org/recipient-detail/3452/yab...
# 3469  http://www.cmohs.org/recipient-detail/3453/yan...
# 3471  http://www.cmohs.org/recipient-detail/3454/ynt...
# 3472  http://www.cmohs.org/recipient-detail/1532/you...
# 3474  http://www.cmohs.org/recipient-detail/1534/you...
#
#        military record.company  \
# 0                    Company B
# 3                          NaN
# 27                   Company A
# 34                   Company F
# 45                         NaN
# ...                        ...
# 3468  Company A, 4th Battalion
# 3469         Air Cavalry Troop
# 3471                 Company D
# 3472                 Company F
# 3474                 Company L
#
#                             military record.division  ... awarded.date.day  \
# 0                             1st New Jersey Cavalry  ...                6
# 3                              1st Infantry Division  ...               10
# 27              242d Infantry, 42d Infantry Division  ...               -1
# 34    223d Infantry Regiment, 40th Infantry Division  ...               -1
# 45                         U.S. Senior Advisor Group  ...               -1
# ...                                              ...  ...              ...
# 3468            9th Infantry, 25th Infantry Division  ...               26
# 3469                   11th Armored Cavalry Regiment  ...                1
# 3471                        5th Special Forces Group  ...               -1
# 3472                        1st Pennsylvania Cavalry  ...                5
# 3474                                 3d Iowa Cavalry  ...               25
#
#      awarded.date.full awarded.date.month  awarded.date.year  \
# 0             1865-2-6                  2               1865
# 3            1944-6-10                  6               1944
# 27            -1--1--1                 -1                 -1
# 34            -1--1--1                 -1                 -1
# 45            -1--1--1                 -1                 -1
# ...                ...                ...                ...
# 3468         1967-2-26                  2               1967
# 3469          1969-1-1                  1               1969
# 3471          -1--1--1                 -1                 -1
# 3472          1865-4-5                  4               1865
# 3474        1864-10-25                 10               1864
#
#      awarded.location.latitude  awarded.location.longitude  \
# 0                           38                         -77
# 3                           49                           0
# 27                          48                           7
# 34                          35                         127
# 45                          10                         106
# ...                        ...                         ...
# 3468                        10                         106
# 3469                        10                         106
# 3471                        10                         106
# 3472                        37                         -78
# 3474                        38                         -95
#
#                                   awarded.location.name  birth.date.day  \
# 0           Hatchers Run Court, Stafford, VA 22554, USA              -1
# 3                                14490 Vaubadon, France              -1
# 27                                       Hatten, France               1
# 34                                          South Korea              30
# 45    Honorary Consulate General of the Republic of ...              14
# ...                                                 ...             ...
# 3468  Honorary Consulate General of the Republic of ...              29
# 3469  Honorary Consulate General of the Republic of ...              13
# 3471  Honorary Consulate General of the Republic of ...              26
# 3472                                      Virginia, USA              -1
# 3474                              Osage County, KS, USA              -1
#
#       birth.date.month birth.date.year
# 0                   -1              -1
# 3                   -1              -1
# 27                  12            1916
# 34                  12            1930
# 45                  12            1944
# ...                ...             ...
# 3468                 1            1932
# 3469                12            1943
# 3471                 6            1945
# 3472                -1              -1
# 3474                -1              -1
#
# [731 rows x 23 columns]
