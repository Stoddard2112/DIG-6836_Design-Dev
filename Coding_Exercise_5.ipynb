# %% [markdown]
# # Pandas Jupyter Experiment
#
# For this exercise, you will be choosing a dataset that is already available in CSV, using either the links suggested in the module or an external source. Note that the completeness and organization of the CSV will impact your success, so you might want to investigate it using our initial methods before you commit to it and your object of analysis.
#
# I have provided the headings for each section: you can modify them to reflect your final workflow. Here's what you need to accomplish and document:
#
# - Complete the five sequential stages of importing, analyzing, and visualizing your CSV data using the Pandas library. The headers are provided, but you will need to plan out and structure what happens in the code using a combination of our class exercise and the textbook for guidance.
#
# - Create a well-structured, readable documentation for every cell of your Python code. Use Markdown (as demonstrated in this example) and preview the results on GitHub to confirm it works as intended.
#
# - As a bonus exercise, output and save a meaningful, formatted visualization, following the examples in the textbook.

# %% [markdown]
# # Stage One: Import Libraries  / Data
#
# THis first cell imports Pandas and changes the name to pd for shorthand.  It then opens a CSV file.  The CSV file must alredy be downloaded and present within the same folder.  Create a name for the file to use throughout the workflow.
#
# For this workflow, I am using a CSV file of servicememebers who were awarded the Medal of Honor (MoH).

# %%
import pandas as pd

moh_df = pd.read_csv('medal_of_honor.csv', delimiter=",")

moh_df
# Out:
#       death                    name  awarded.General Order number  \
# 0      True     Sagelhurst, John C.                            -1
# 1      True              Hack, John                            -1
# 2      True      Carson, Anthony J.                            -1
# 3      True    Defranzos, Arthur F.                             1
# 4      True     Kessler, Patrick L.                             1
# ...     ...                     ...                           ...
# 3470   True        Yeager, Jacob F.                            -1
# 3471   True  Yntema, Gordon Douglas                            -1
# 3472   True        Young, Andrew J.                            -1
# 3473   True      Young, Benjamin F.                            -1
# 3474   True       Young, Calvary M.                            -1
#
#      awarded.accredited to                                   awarded.citation  \
# 0                      NaN  Under a heavy fire from the enemy carried off ...
# 1                      NaN  Was one of a party which volunteered and attem...
# 2                      NaN  Assumed command of a detachment of the company...
# 3                      NaN  For conspicuous gallantry and intrepidity at t...
# 4                      NaN  For conspicuous gallantry and intrepidity at r...
# ...                    ...                                                ...
# 3470                   NaN  Seized a shell with fuze burning that had fall...
# 3471                   NaN  For conspicuous gallantry and intrepidity in a...
# 3472                   NaN                                   Capture of flag.
# 3473                   NaN  Capture of flag of 35th North Carolina Infantr...
# 3474                   NaN                Gallantry in capturing Gen. Cabell.
#
#      awarded.issued      birth.location name  \
# 0        01/03/1906            Buffalo, N.Y.
# 1        01/03/1907            1843, Germany
# 2        01/04/1906            Boston, Mass.
# 3        01/04/1945            Saugus, Mass.
# 4        01/04/1945         Middletown, Ohio
# ...             ...                      ...
# 3470              ?       Lehigh County, Pa.
# 3471              ?            Bethesda, Md.
# 3472              ?       Greene County, Pa.
# 3473              ?             1844, Canada
# 3474              ?  Washington County, Ohio
#
#                                           metadata.link  \
# 0     http://www.cmohs.org/recipient-detail/1176/sag...
# 1     http://www.cmohs.org/recipient-detail/537/hack...
# 2     http://www.cmohs.org/recipient-detail/2211/car...
# 3     http://www.cmohs.org/recipient-detail/2710/def...
# 4     http://www.cmohs.org/recipient-detail/2824/kes...
# ...                                                 ...
# 3470  http://www.cmohs.org/recipient-detail/1531/yea...
# 3471  http://www.cmohs.org/recipient-detail/3454/ynt...
# 3472  http://www.cmohs.org/recipient-detail/1532/you...
# 3473  http://www.cmohs.org/recipient-detail/1533/you...
# 3474  http://www.cmohs.org/recipient-detail/1534/you...
#
#      military record.company             military record.division  ...  \
# 0                  Company B               1st New Jersey Cavalry  ...
# 1                  Company B                   47th Ohio Infantry  ...
# 2                  Company H                         43d Infantry  ...
# 3                        NaN                1st Infantry Division  ...
# 4                  Company K  30th Infantry, 3d Infantry Division  ...
# ...                      ...                                  ...  ...
# 3470               Company H                  101st Ohio Infantry  ...
# 3471               Company D             5th Special Forces Group  ...
# 3472               Company F             1st Pennsylvania Cavalry  ...
# 3473               Company I           1st Michigan Sharpshooters  ...
# 3474               Company L                      3d Iowa Cavalry  ...
#
#      awarded.date.day awarded.date.full awarded.date.month  awarded.date.year  \
# 0                   6          1865-2-6                  2               1865
# 1                   3          1863-5-3                  5               1863
# 2                  -1          -1--1--1                 -1                 -1
# 3                  10         1944-6-10                  6               1944
# 4                  23         1944-5-23                  5               1944
# ...               ...               ...                ...                ...
# 3470               11         1864-5-11                  5               1864
# 3471               -1          -1--1--1                 -1                 -1
# 3472                5          1865-4-5                  4               1865
# 3473               17         1864-6-17                  6               1864
# 3474               25        1864-10-25                 10               1864
#
#      awarded.location.latitude  awarded.location.longitude  \
# 0                           38                         -77
# 1                           32                         -90
# 2                           10                         124
# 3                           49                           0
# 4                           43                          11
# ...                        ...                         ...
# 3470                        31                         -81
# 3471                        10                         106
# 3472                        37                         -78
# 3473                        37                         -77
# 3474                        38                         -95
#
#                                   awarded.location.name  birth.date.day  \
# 0           Hatchers Run Court, Stafford, VA 22554, USA              -1
# 1                                    Vicksburg, MS, USA              -1
# 2                                    Leyte, Philippines              -1
# 3                                14490 Vaubadon, France              -1
# 4                           50026 Ponte Rotto FI, Italy              -1
# ...                                                 ...             ...
# 3470           Buzzards Roost, Brunswick, GA 31520, USA              -1
# 3471  Honorary Consulate General of the Republic of ...              26
# 3472                                      Virginia, USA              -1
# 3473                                Petersburg, VA, USA              -1
# 3474                              Osage County, KS, USA              -1
#
#       birth.date.month birth.date.year
# 0                   -1              -1
# 1                   -1              -1
# 2                   -1              -1
# 3                   -1              -1
# 4                   -1              -1
# ...                ...             ...
# 3470                -1              -1
# 3471                 6            1945
# 3472                -1              -1
# 3473                -1              -1
# 3474                -1              -1
#
# [3475 rows x 23 columns]

# %% [markdown]
# # Stage Two: Display a Summary and Sub-sections of the Data
#
# This following 3 cells uses different codes to filter and view the data.  Section 1 prints a random sample of the data.  In this case, 10 random MoH earners.  Section 2 prints the minimum and maximum award year of MoH's.  THis should print the first year and last year of the award, per this dataset.  Section 3 prints the number of MoH awards by branch.  THis will show the distrobution of the award accross the branches.

# %%
# Section 1
moh_df.sample(10)
# Out:
#       death                   name  awarded.General Order number  \
# 3283   True        Wai, Francis B.                            -1
# 2125   True  Kraus, Richard Edward                            -1
# 2593   True             Orr, Moses                            -1
# 2170   True         Lejeune, Emile                           212
# 1874   True          Holden, Henry                            -1
# 481    True       Collier, John W.                            86
# 3302   True       Ward, Charles H.                            -1
# 1581   True     Fraser, William W.                            -1
# 2883   True        Savage, Auzella                            59
# 2967   True          Shutes, Henry                            71
#
#      awarded.accredited to                                   awarded.citation  \
# 3283                   NaN  Captain Francis B. Wai distinguished himself b...
# 2125             Minnesota  For conspicuous gallantry and intrepidity at t...
# 2593                   NaN  Gallant conduct during cam paigns and engageme...
# 2170              New York  Serving on board the U.S.S. Plymouth, Lejeune ...
# 1874                   NaN  Brought up ammunition under a galling fire fro...
# 481                    NaN  Cpl. Collier, Company C, distinguished himself...
# 3302                   NaN                  Gallantry in action with Indians.
# 1581                   NaN  Gallantry in the charge of the "volunteer stor...
# 2883         Massachusetts  On board the U.S.S. Santiago de Cuba in the as...
# 2967              Maryland  Served as captain of the forecastle on board t...
#
#      awarded.issued   birth.location name  \
# 3283              ?                   NaN
# 2125              ?         Chicago, Ill.
# 2593              ?               Ireland
# 2170              ?          1853, France
# 1874              ?               England
# 481      08/02/1951      Worthington, Ky.
# 3302              ?               England
# 1581              ?              Scotland
# 2883              ?           1846, Maine
# 2967              ?  1804, Baltimore, Md.
#
#                                           metadata.link  \
# 3283  http://www.cmohs.org/recipient-detail/3043/wai...
# 2125  http://www.cmohs.org/recipient-detail/2835/kra...
# 2593  http://www.cmohs.org/recipient-detail/1827/orr...
# 2170  http://www.cmohs.org/recipient-detail/2032/lej...
# 1874  http://www.cmohs.org/recipient-detail/1701/hol...
# 481   http://www.cmohs.org/recipient-detail/3097/col...
# 3302  http://www.cmohs.org/recipient-detail/1930/war...
# 1581  http://www.cmohs.org/recipient-detail/461/fras...
# 2883  http://www.cmohs.org/recipient-detail/1185/sav...
# 2967  http://www.cmohs.org/recipient-detail/1243/shu...
#
#      military record.company military record.division  ... awarded.date.day  \
# 3283                     NaN                      NaN  ...               -1
# 2125                     NaN                      NaN  ...               -1
# 2593               Company A         1st U.S. Cavalry  ...               -1
# 2170                     NaN                      NaN  ...               -1
# 1874               Company D         7th U.S. Cavalry  ...               25
# 481                Company C   27th Infantry Regiment  ...               19
# 3302               Company G         1st U.S. Cavalry  ...               20
# 1581               Company I   97th Illinois Infantry  ...               22
# 2883                     NaN                      NaN  ...               -1
# 2967                     NaN                      NaN  ...               -1
#
#      awarded.date.full awarded.date.month  awarded.date.year  \
# 3283          -1--1--1                 -1                 -1
# 2125          -1--1--1                 -1                 -1
# 2593          -1--1--1                 -1                 -1
# 2170          -1--1--1                 -1                 -1
# 1874         1876-6-25                  6               1876
# 481          1950-9-19                  9               1950
# 3302        1869-10-20                 10               1869
# 1581         1863-5-22                  5               1863
# 2883          -1--1--1                 -1                 -1
# 2967          -1--1--1                 -1                 -1
#
#      awarded.location.latitude  awarded.location.longitude  \
# 3283                        -1                          -1
# 2125                         7                         134
# 2593                        37                         -95
# 2170                        32                         -80
# 1874                        45                        -107
# 481                         35                         127
# 3302                        31                        -109
# 1581                        32                         -90
# 2883                        33                         -77
# 2967                        29                         -90
#
#                                   awarded.location.name  birth.date.day  \
# 3283                                            Unknown              -1
# 2125                 Palau Islands, Ngaremlengui, Palau              24
# 2593                                      United States              -1
# 2170                                Port Royal, SC, USA              -1
# 1874                 Little Bighorn River, Montana, USA              -1
# 481                                         South Korea               3
# 3302  Chiricahua Mountains, Coronado National Forest...              -1
# 1581                                 Vicksburg, MS, USA              -1
# 2883  Fort Fisher Historic Museum, 1610 South Fort F...              -1
# 2967                               New Orleans, LA, USA              -1
#
#       birth.date.month birth.date.year
# 3283                -1              -1
# 2125                11            1925
# 2593                -1              -1
# 2170                -1              -1
# 1874                -1              -1
# 481                  4            1929
# 3302                -1              -1
# 1581                -1              -1
# 2883                -1              -1
# 2967                -1              -1
#
# [10 rows x 23 columns]

# %%
# Section 2
print(moh_df['awarded.date.year'].min())
print(moh_df['awarded.date.year'].max())
# The -1 printed reflects negative data in these columns.  Potetially becasue award year was unavailable.
# Out:
# -1
# 2007

# %%
# Section 3
moh_df['military record.organization'].value_counts()
# Out:
# U.S. Army            2428
# U.S. Navy             734
# U.S. Marine Corps     295
# U.S. Air Force         17
# U.S. Coast Guard        1
# Name: military record.organization, dtype: int64

# %% [markdown]
# # Stage Three: Clean Your Data
#
# (Varies by dataset: you might replace missing values with a filler, replace shorthand from the dataset with readable language, and/or delete duplicates)

# %% [markdown]
# # Stage Four: Plot Your Data
#
# (Try at least three different plots - bar, hist, box, area, scatter, hexbin, and pie are all worth viewing - and describe your choices)

# %% [markdown]
# # Stage Five: Draw Comparisons and Make Claims
#
# (Think of all the methods we've used so far - what might you analyze about this dataset? This section can mostly be commentary drawing on what you've found so far)

# %% [markdown]
# # Bonus: Export a Meaningful Visualization
#
# (Use the guidance in the book to get started!)
