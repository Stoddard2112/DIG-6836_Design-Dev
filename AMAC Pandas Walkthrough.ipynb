# %% [markdown]
# # AMAC Pandas Processing
#
# This demo works through importing pandas and using it to research a csv file.  CSV file must be found and imported.

# %%
# Review class recording to find CSV on kaggle.  Most open CSV in VSC prior to importing.  Is there a military awards csv, MoH?

# Iports pandas and changes the name to shorthand pd
import pandas as pd

#create a dataframe object from a csv
# Takes already sorted CSV data and resorts for our use.
# tell pandas to read a file name within the () and 
amac_df = pd.read_csv('amac_inter_data_clean.csv', delimiter=",")

amac_df
# Out:
#      Last Name First Name Middle Name Suffix                 Rank  \
# 0       Abbott       Leon           E    NaN              Private
# 1       Abbott       Mike         NaN    NaN              Private
# 2      Aberman      Harry         NaN    NaN              Private
# 3       Abrams     Edward           B    NaN             Corporal
# 4        Acree     Auther         NaN    NaN  Private First Class
# ...        ...        ...         ...    ...                  ...
# 3343    Zirbes    Anthony           W    NaN              Private
# 3344   Ziriske       John         NaN    NaN              Private
# 3345   Zlotcha       Mike         NaN    NaN              Private
# 3346       Zok        Joe           E    NaN              Private
# 3347    Zornes     George         NaN    NaN              Private
#
#                  Branch field_place_of_entry  Day of Death Month of Death  \
# 0             U.S. Army        Massachusetts          13.0           July
# 1             U.S. Army             New York          18.0           July
# 2             U.S. Army         Pennsylvania          26.0           July
# 3     U.S. Marine Corps           New Jersey          12.0           June
# 4             U.S. Army              Alabama          15.0           July
# ...                 ...                  ...           ...            ...
# 3343          U.S. Army         North Dakota          22.0           July
# 3344          U.S. Army             New York          18.0           July
# 3345          U.S. Army             Michigan          23.0      September
# 3346          U.S. Army              Montana          15.0           July
# 3347          U.S. Army                 Ohio          13.0           June
#
#       Year of Death Plot   Row  Grave   Memorialized Location  \
# 0            1918.0    A  13.0   70.0                     NaN
# 1            1918.0  NaN   NaN    NaN  Tablets of the Missing
# 2            1918.0    A  10.0   11.0                     NaN
# 3            1918.0  NaN   NaN    NaN  Tablets of the Missing
# 4            1918.0    B  11.0   19.0                     NaN
# ...             ...  ...   ...    ...                     ...
# 3343         1918.0  NaN   NaN    NaN  Tablets of the Missing
# 3344         1918.0  NaN   NaN    NaN  Tablets of the Missing
# 3345         1918.0    B   1.0   85.0                     NaN
# 3346         1918.0  NaN   NaN    NaN  Tablets of the Missing
# 3347         1918.0    A   3.0   21.0                     NaN
#
#                  Cemetery/Memorial  War/Conflict Awards  \
# 0     Aisne-Marne American Cemetery  World War I    NaN
# 1     Aisne-Marne American Cemetery  World War I    NaN
# 2     Aisne-Marne American Cemetery  World War I    NaN
# 3     Aisne-Marne American Cemetery  World War I    NaN
# 4     Aisne-Marne American Cemetery  World War I    NaN
# ...                             ...          ...    ...
# 3343  Aisne-Marne American Cemetery  World War I    NaN
# 3344  Aisne-Marne American Cemetery  World War I    NaN
# 3345  Aisne-Marne American Cemetery  World War I    NaN
# 3346  Aisne-Marne American Cemetery  World War I    NaN
# 3347  Aisne-Marne American Cemetery  World War I    NaN
#
#                             ABMC Burial Unit
# 0     101st Infantry Regiment, 26th Division
# 1        9th Infantry Regiment, 2nd Division
# 2        4th Infantry Regiment, 3rd Division
# 3            5th USMC Regiment, 2nd Division
# 4     167th Infantry Regiment, 42nd Division
# ...                                      ...
# 3343    26th Infantry Regiment, 1st Division
# 3344     9th Infantry Regiment, 2nd Division
# 3345  339th Infantry Regiment, 85th Division
# 3346     6th Engineer Regiment, 3rd Division
# 3347     2nd Engineer Regiment, 2nd Division
#
# [3348 rows x 18 columns]

# %%
# Prints top 10 rows plus header
amac_df.head(10)
# Out:
#   Last Name First Name Middle Name Suffix                 Rank  \
# 0    Abbott       Leon           E    NaN              Private
# 1    Abbott       Mike         NaN    NaN              Private
# 2   Aberman      Harry         NaN    NaN              Private
# 3    Abrams     Edward           B    NaN             Corporal
# 4     Acree     Auther         NaN    NaN  Private First Class
# 5     Adach  Konstanty         NaN    NaN  Private First Class
# 6    Adamec        Joe         NaN    NaN  Private First Class
# 7     Adams    Halbert         NaN    NaN              Private
# 8     Adams     Walter           R    NaN                Clerk
# 9   Adamson     Robert           L    NaN  Private First Class
#
#               Branch field_place_of_entry  Day of Death Month of Death  \
# 0          U.S. Army        Massachusetts          13.0           July
# 1          U.S. Army             New York          18.0           July
# 2          U.S. Army         Pennsylvania          26.0           July
# 3  U.S. Marine Corps           New Jersey          12.0           June
# 4          U.S. Army              Alabama          15.0           July
# 5          U.S. Army             New York          23.0           June
# 6          U.S. Army              Indiana          14.0       November
# 7          U.S. Army              Alabama          28.0           July
# 8          U.S. Army             Missouri          19.0           July
# 9          U.S. Army            Minnesota           6.0         August
#
#    Year of Death Plot   Row  Grave   Memorialized Location  \
# 0         1918.0    A  13.0   70.0                     NaN
# 1         1918.0  NaN   NaN    NaN  Tablets of the Missing
# 2         1918.0    A  10.0   11.0                     NaN
# 3         1918.0  NaN   NaN    NaN  Tablets of the Missing
# 4         1918.0    B  11.0   19.0                     NaN
# 5         1918.0    B   2.0   10.0                     NaN
# 6         1918.0    B   8.0   16.0                     NaN
# 7         1918.0  NaN   NaN    NaN  Tablets of the Missing
# 8         1918.0  NaN   NaN    NaN  Tablets of the Missing
# 9         1918.0    B   2.0   38.0                     NaN
#
#               Cemetery/Memorial  War/Conflict                  Awards  \
# 0  Aisne-Marne American Cemetery  World War I                     NaN
# 1  Aisne-Marne American Cemetery  World War I                     NaN
# 2  Aisne-Marne American Cemetery  World War I                     NaN
# 3  Aisne-Marne American Cemetery  World War I                     NaN
# 4  Aisne-Marne American Cemetery  World War I                     NaN
# 5  Aisne-Marne American Cemetery  World War I                     NaN
# 6  Aisne-Marne American Cemetery  World War I  French Croix de Guerre
# 7  Aisne-Marne American Cemetery  World War I                     NaN
# 8  Aisne-Marne American Cemetery  World War I                     NaN
# 9  Aisne-Marne American Cemetery  World War I                     NaN
#
#                          ABMC Burial Unit
# 0  101st Infantry Regiment, 26th Division
# 1     9th Infantry Regiment, 2nd Division
# 2     4th Infantry Regiment, 3rd Division
# 3         5th USMC Regiment, 2nd Division
# 4  167th Infantry Regiment, 42nd Division
# 5    23rd Infantry Regiment, 2nd Division
# 6    16th Infantry Regiment, 1st Division
# 7  167th Infantry Regiment, 42nd Division
# 8    16th Infantry Regiment, 1st Division
# 9    58th Infantry Regiment, 4th Division

# %%
# Prints the min, mean, and max of a time, date, year...
print(amac_df['awarded.date.year'].min())
print(amac_df['awarded.date.year'].mean())
print(amac_df['awarded.date.year'].max())
print(amac_df['birth.date.year'].min())
print(amac_df['birth.date.year'].mean())
print(amac_df['birth.date.year'].max())
# The -1 printed reflects unavailable data in these columns.  Potetially becasue data was unavailable, especially for birth year.
# The decimal numbers reflect the math done to achive a mean of the numbers, not an actual mean year.
# Out:
# -1
# 1200.1476258992807
# 2007
# -1
# 605.0705035971223
# 1988

# %%
# Gives arandom sample of data within the provided range
amac_df.sample(10)
# Out:
#       Last Name First Name Middle Name Suffix                 Rank  \
# 2362  Rorabaugh         Ad         NaN    NaN              Private
# 1900     Miller      Henry           L    NaN              Private
# 2053    O'Brien    Charles         NaN    NaN     First Lieutenant
# 3319      Wylie     Arthur           C    NaN  Private First Class
# 544    Costigan      James           W    NaN              Private
# 2983    Unknown        NaN         NaN    NaN                  NaN
# 1789    McClain    Burnird           C    NaN              Private
# 2179   Peterson      Elmer         NaN    NaN              Private
# 2893    Unknown        NaN         NaN    NaN                  NaN
# 2245    Pulliam        Joe           D    NaN              Private
#
#                  Branch field_place_of_entry  Day of Death Month of Death  \
# 2362          U.S. Army             Nebraska          18.0           July
# 1900          U.S. Army              Montana          20.0           July
# 2053          U.S. Army         Pennsylvania           5.0      September
# 3319          U.S. Army              Georgia          18.0           July
# 544   U.S. Marine Corps             Kentucky          31.0           July
# 2983            Unknown                  NaN           NaN            NaN
# 1789          U.S. Army        West Virginia          18.0           July
# 2179          U.S. Army         North Dakota          28.0        October
# 2893            Unknown                  NaN           NaN            NaN
# 2245          U.S. Army             Virginia           3.0           July
#
#       Year of Death Plot   Row  Grave   Memorialized Location  \
# 2362         1918.0  NaN   NaN    NaN  Tablets of the Missing
# 1900         1918.0  NaN   NaN    NaN  Tablets of the Missing
# 2053         1918.0    B   1.0   65.0                     NaN
# 3319         1918.0  NaN   NaN    NaN  Tablets of the Missing
# 544          1918.0    A   3.0   46.0                     NaN
# 2983            NaN    B  13.0   84.0                     NaN
# 1789         1918.0  NaN   NaN    NaN  Tablets of the Missing
# 2179         1918.0    B   9.0    4.0                     NaN
# 2893            NaN    B  11.0    1.0                     NaN
# 2245         1918.0    A   2.0   79.0                     NaN
#
#                  Cemetery/Memorial  War/Conflict                       Awards  \
# 2362  Aisne-Marne American Cemetery  World War I                          NaN
# 1900  Aisne-Marne American Cemetery  World War I                          NaN
# 2053  Aisne-Marne American Cemetery  World War I  Distinguished Service Cross
# 3319  Aisne-Marne American Cemetery  World War I                          NaN
# 544   Aisne-Marne American Cemetery  World War I                          NaN
# 2983  Aisne-Marne American Cemetery  World War I                          NaN
# 1789  Aisne-Marne American Cemetery  World War I                          NaN
# 2179  Aisne-Marne American Cemetery  World War I                          NaN
# 2893  Aisne-Marne American Cemetery  World War I                          NaN
# 2245  Aisne-Marne American Cemetery  World War I                          NaN
#
#                                    ABMC Burial Unit
# 2362           23rd Infantry Regiment, 2nd Division
# 1900           16th Infantry Regiment, 1st Division
# 2053         306th Infantry Regiment, 77th Division
# 3319            9th Infantry Regiment, 2nd Division
# 544                 6th USMC Regiment, 2nd Division
# 2983                                            NaN
# 1789           28th Infantry Regiment, 1st Division
# 2179  339th Field Artillery Regiment, 88th Division
# 2893                                            NaN
# 2245        2nd Trench Mortar Battery, 2nd Division

# %%
# I think this breaks out various aspects of data, like proportions
amac_df.describe(include='all')
# Out:
#        Last Name First Name Middle Name Suffix     Rank     Branch  \
# count       3348       3099        2012     29     3097       3346
# unique      2420        696          26      1       32          4
# top      Unknown       John           J    Jr.  Private  U.S. Army
# freq         249        203         202     29     1780       2619
# mean         NaN        NaN         NaN    NaN      NaN        NaN
# std          NaN        NaN         NaN    NaN      NaN        NaN
# min          NaN        NaN         NaN    NaN      NaN        NaN
# 25%          NaN        NaN         NaN    NaN      NaN        NaN
# 50%          NaN        NaN         NaN    NaN      NaN        NaN
# 75%          NaN        NaN         NaN    NaN      NaN        NaN
# max          NaN        NaN         NaN    NaN      NaN        NaN
#
#        field_place_of_entry  Day of Death Month of Death  Year of Death  Plot  \
# count                  3099   3099.000000           3099    3099.000000  2288
# unique                   50           NaN             12            NaN     2
# top                New York           NaN           July            NaN     A
# freq                    365           NaN           1874            NaN  1172
# mean                    NaN     16.030655            NaN    1918.012907   NaN
# std                     NaN      7.609372            NaN       0.126384   NaN
# min                     NaN      1.000000            NaN    1917.000000   NaN
# 25%                     NaN     10.000000            NaN    1918.000000   NaN
# 50%                     NaN     18.000000            NaN    1918.000000   NaN
# 75%                     NaN     21.000000            NaN    1918.000000   NaN
# max                     NaN     31.000000            NaN    1921.000000   NaN
#
#                 Row        Grave   Memorialized Location  \
# count   2288.000000  2288.000000                    1060
# unique          NaN          NaN                       2
# top             NaN          NaN  Tablets of the Missing
# freq            NaN          NaN                    1059
# mean       7.013986    44.524038                     NaN
# std        3.823817    25.475630                     NaN
# min        1.000000     1.000000                     NaN
# 25%        4.000000    22.000000                     NaN
# 50%        7.000000    44.500000                     NaN
# 75%       10.000000    66.250000                     NaN
# max       45.000000    91.000000                     NaN
#
#                    Cemetery/Memorial  War/Conflict                  Awards  \
# count                            3348         3348                     137
# unique                              1            1                      12
# top     Aisne-Marne American Cemetery  World War I  French Croix de Guerre
# freq                             3348         3348                      68
# mean                              NaN          NaN                     NaN
# std                               NaN          NaN                     NaN
# min                               NaN          NaN                     NaN
# 25%                               NaN          NaN                     NaN
# 50%                               NaN          NaN                     NaN
# 75%                               NaN          NaN                     NaN
# max                               NaN          NaN                     NaN
#
#                        ABMC Burial Unit
# count                              3092
# unique                              220
# top     5th USMC Regiment, 2nd Division
# freq                                281
# mean                                NaN
# std                                 NaN
# min                                 NaN
# 25%                                 NaN
# 50%                                 NaN
# 75%                                 NaN
# max                                 NaN

# %%
# Prints the count of a particualr vaule within a column
amac_df['Branch'].value_counts()
# Out:
# U.S. Army            2619
# U.S. Marine Corps     474
# Unknown               249
# U.S. Navy               4
# Name: Branch, dtype: int64

# %%
amac_df['Rank'].value_counts()
# Out:
# Private                            1780
# Private First Class                 495
# Corporal                            400
# Sergeant                            163
# Second Lieutenant                    65
# First Lieutenant                     61
# Bugler                               20
# Clerk                                15
# Sergeant First Class                 14
# Mechanic                             14
# Wagoner                              13
# First Sergeant                       11
# Supply Sergeant                       7
# Captain                               6
# Mess Sergeant                         6
# Gunnery Sergeant                      5
# Musician Third Class                  3
# Horseshoer                            2
# Station Sergeant                      2
# Major                                 2
# Drummer                               2
# Hospital Apprentice First Class       1
# Cook                                  1
# Brigadier General                     1
# Sergeant  Bugler                      1
# Color Sergeant                        1
# Lieutenant Junior Grade               1
# Sergeant Major                        1
# Pharmacist Mate Second Class          1
# Lieutenant Colonel                    1
# Gunner                                1
# Pattern Maker Second Class            1
# Name: Rank, dtype: int64

# %%
# Prints the top X counts of a particular value.  In this case the 10 names that occur the most.
amac_df['field_place_of_entry'].value_counts()[:10]
# Out:
# New York         365
# Pennsylvania     342
# Massachusetts    252
# Illinois         179
# Ohio             148
# Michigan         138
# Wisconsin        117
# California        97
# New Jersey        93
# Connecticut       84
# Name: field_place_of_entry, dtype: int64

# %%
# Visualization.  15 vaule counts, plots out as a bar horizontl, gives title of plot.  
# Pandas is great at making good looking visualizations.  Refer to pandas website.
# This cell created a bar graph numbers of MoH by branch.
amac_df['Branch'].value_counts()[:4].plot(kind="barh", title="Deaths by Branch")

# %%
amac_df['Rank'].value_counts()[:7].plot(kind="pie", title="Most Deaths by Rank")

# %%
amac_df['Awards'].value_counts()[:5].plot(kind="barh", title="Awards")

# %%
amac_df['Month of Death'].value_counts()[:5].plot(kind="pie", title="Deadliest Months of 1918")

# %%
# Utility function for running queries on data.  
# for Oscar demo: In this case searching awards without a film attached, ex lifetime achievement awards.
# For MoH work, this query doesn't seem to apply.  It runs succesfully, but no reulst apply, maybe.
moh_df['birth.date.year'] = moh_df['birth.date.year'].fillna('No birth year available')

# %%
# This queries the rank column for all earning MoH with the rank of sergeant. 
moh_df[moh_df['military record.rank'].str.contains('Sergeant')]
# Out:
#       death                    name  awarded.General Order number  \
# 0      True     Sagelhurst, John C.                            -1
# 3      True    Defranzos, Arthur F.                             1
# 27     True       Bertoldo, Vito R.                            -1
# 34     True     Collier, Gilbert G.                             3
# 45     True        Dix, Drew Dennis                            -1
# ...     ...                     ...                           ...
# 3468   True           Yabes, Maximo                            -1
# 3469   True      Yano, Rodney J. T.                            -1
# 3471   True  Yntema, Gordon Douglas                            -1
# 3472   True        Young, Andrew J.                            -1
# 3474   True       Young, Calvary M.                            -1
#
#      awarded.accredited to                                   awarded.citation  \
# 0                      NaN  Under a heavy fire from the enemy carried off ...
# 3                      NaN  For conspicuous gallantry and intrepidity at t...
# 27                     NaN  He fought with extreme gallantry while guardin...
# 34                     NaN  Sgt. Collier, a member of Company F, distingui...
# 45              Denver, CO  For conspicuous gallantry and intrepidity in a...
# ...                    ...                                                ...
# 3468                   NaN  For conspicuous gallantry and intrepidity at t...
# 3469                   NaN  Sfc. Yano distinguished himself while serving ...
# 3471                   NaN  For conspicuous gallantry and intrepidity in a...
# 3472                   NaN                                   Capture of flag.
# 3474                   NaN                Gallantry in capturing Gen. Cabell.
#
#      awarded.issued       birth.location name  \
# 0        01/03/1906             Buffalo, N.Y.
# 3        01/04/1945             Saugus, Mass.
# 27       01/10/1946             Decatur, Ill.
# 34       01/12/1955              Hunter, Ark.
# 45       01/16/1969          West Point, N.Y.
# ...             ...                       ...
# 3468              ?              Lodi, Calif.
# 3469              ?   Kealakekua Kona, Hawaii
# 3471              ?             Bethesda, Md.
# 3472              ?        Greene County, Pa.
# 3474              ?   Washington County, Ohio
#
#                                           metadata.link  \
# 0     http://www.cmohs.org/recipient-detail/1176/sag...
# 3     http://www.cmohs.org/recipient-detail/2710/def...
# 27    http://www.cmohs.org/recipient-detail/2637/ber...
# 34    http://www.cmohs.org/recipient-detail/3096/col...
# 45    http://www.cmohs.org/recipient-detail/3263/dix...
# ...                                                 ...
# 3468  http://www.cmohs.org/recipient-detail/3452/yab...
# 3469  http://www.cmohs.org/recipient-detail/3453/yan...
# 3471  http://www.cmohs.org/recipient-detail/3454/ynt...
# 3472  http://www.cmohs.org/recipient-detail/1532/you...
# 3474  http://www.cmohs.org/recipient-detail/1534/you...
#
#        military record.company  \
# 0                    Company B
# 3                          NaN
# 27                   Company A
# 34                   Company F
# 45                         NaN
# ...                        ...
# 3468  Company A, 4th Battalion
# 3469         Air Cavalry Troop
# 3471                 Company D
# 3472                 Company F
# 3474                 Company L
#
#                             military record.division  ... awarded.date.day  \
# 0                             1st New Jersey Cavalry  ...                6
# 3                              1st Infantry Division  ...               10
# 27              242d Infantry, 42d Infantry Division  ...               -1
# 34    223d Infantry Regiment, 40th Infantry Division  ...               -1
# 45                         U.S. Senior Advisor Group  ...               -1
# ...                                              ...  ...              ...
# 3468            9th Infantry, 25th Infantry Division  ...               26
# 3469                   11th Armored Cavalry Regiment  ...                1
# 3471                        5th Special Forces Group  ...               -1
# 3472                        1st Pennsylvania Cavalry  ...                5
# 3474                                 3d Iowa Cavalry  ...               25
#
#      awarded.date.full awarded.date.month  awarded.date.year  \
# 0             1865-2-6                  2               1865
# 3            1944-6-10                  6               1944
# 27            -1--1--1                 -1                 -1
# 34            -1--1--1                 -1                 -1
# 45            -1--1--1                 -1                 -1
# ...                ...                ...                ...
# 3468         1967-2-26                  2               1967
# 3469          1969-1-1                  1               1969
# 3471          -1--1--1                 -1                 -1
# 3472          1865-4-5                  4               1865
# 3474        1864-10-25                 10               1864
#
#      awarded.location.latitude  awarded.location.longitude  \
# 0                           38                         -77
# 3                           49                           0
# 27                          48                           7
# 34                          35                         127
# 45                          10                         106
# ...                        ...                         ...
# 3468                        10                         106
# 3469                        10                         106
# 3471                        10                         106
# 3472                        37                         -78
# 3474                        38                         -95
#
#                                   awarded.location.name  birth.date.day  \
# 0           Hatchers Run Court, Stafford, VA 22554, USA              -1
# 3                                14490 Vaubadon, France              -1
# 27                                       Hatten, France               1
# 34                                          South Korea              30
# 45    Honorary Consulate General of the Republic of ...              14
# ...                                                 ...             ...
# 3468  Honorary Consulate General of the Republic of ...              29
# 3469  Honorary Consulate General of the Republic of ...              13
# 3471  Honorary Consulate General of the Republic of ...              26
# 3472                                      Virginia, USA              -1
# 3474                              Osage County, KS, USA              -1
#
#       birth.date.month birth.date.year
# 0                   -1              -1
# 3                   -1              -1
# 27                  12            1916
# 34                  12            1930
# 45                  12            1944
# ...                ...             ...
# 3468                 1            1932
# 3469                12            1943
# 3471                 6            1945
# 3472                -1              -1
# 3474                -1              -1
#
# [731 rows x 23 columns]
